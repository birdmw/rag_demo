# %%
import sqlite3
import numpy as np
from openai import OpenAI
import os
from tqdm.notebook import tqdm
import time
import requests
from requests.exceptions import Timeout

# Import the API key from config.py
try:
    from config import OPENAI_API_KEY
except ImportError:
    raise ImportError("Please create a config.py file with your OPENAI_API_KEY")

print("Setting up OpenAI client...")
client = OpenAI(api_key=OPENAI_API_KEY)

print("Initializing database...")
conn = sqlite3.connect('p2025_pyramid.sqlite')
cursor = conn.cursor()

print("Creating tables if not exist...")
cursor.execute('''
CREATE TABLE IF NOT EXISTS document_chunks
(id INTEGER PRIMARY KEY, content TEXT, embedding BLOB, shape TEXT, layer INTEGER)
''')

def encode_text(text, max_retries=10, backoff_factor=2, timeout=30):
    print(f"Starting to encode text of length {len(text)}")
    for attempt in range(max_retries):
        try:
            print(f"Attempt {attempt + 1} to encode text")
            response = client.embeddings.create(
                model="text-embedding-ada-002",
                input=[text],
                timeout=timeout
            )
            embedding = np.array(response.data[0].embedding)
            print(f"Successfully encoded text")
            return embedding, embedding.shape
        except Timeout:
            wait_time = backoff_factor * (2 ** attempt)
            print(f"Request timed out. Retrying in {wait_time} seconds...")
            time.sleep(wait_time)
        except Exception as e:
            wait_time = backoff_factor * (2 ** attempt)
            print(f"Error occurred: {e}. Retrying in {wait_time} seconds...")
            time.sleep(wait_time)
    print("Failed to encode text after all attempts")
    raise Exception("Failed to encode text after all attempts")

def add_chunk(content, embedding, shape, layer):
    cursor.execute('INSERT INTO document_chunks (content, embedding, shape, layer) VALUES (?, ?, ?, ?)',
                   (content, ','.join(map(str, embedding)), str(shape), layer))
    conn.commit()

def read_and_chunk_file(file_path, chunk_size=3500, overlap=500):
    print(f"Reading file: {file_path}")
    chunks = []
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
    
    print(f"Chunking file (chunk size: {chunk_size}, overlap: {overlap})")
    start = 0
    with tqdm(total=len(content), desc="Chunking progress") as pbar:
        while start < len(content):
            end = start + chunk_size
            chunk = content[start:end]
            
            if end < len(content):
                sentence_end = chunk.rfind('.')
                paragraph_end = chunk.rfind('\n')
                if sentence_end > 0:
                    end = start + sentence_end + 1
                elif paragraph_end > 0:
                    end = start + paragraph_end + 1
            
            chunks.append(content[start:end])
            start = end - overlap
            pbar.update(end - start)
    
    print(f"Created {len(chunks)} chunks")
    return chunks

def summarize_pair(chunk1, chunk2):
    system_message = "You are an AI assistant tasked with summarizing text. Provide a concise summary that captures the key points of the given text."
    user_message = f"Summarize the following text:\n\n{chunk1}\n\n{chunk2}"
    
    response = client.chat.completions.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": system_message},
            {"role": "user", "content": user_message}
        ]
    )
    return response.choices[0].message.content.strip()

def create_summary_pyramid(chunks, max_layers=5):
    pyramid = [chunks]  # Bottom layer
    
    for layer in range(1, max_layers):
        print(f"Creating layer {layer}...")
        new_layer = []
        for i in range(0, len(pyramid[-1]), 2):
            if i + 1 < len(pyramid[-1]):
                combined = summarize_pair(pyramid[-1][i], pyramid[-1][i+1])
            else:
                combined = pyramid[-1][i]  # If odd number, keep last chunk as is
            new_layer.append(combined)
        
        pyramid.append(new_layer)
        
        if len(new_layer) == 1:
            break  # We've reached the top of the pyramid
    
    return pyramid

print("Reading and chunking file...")
chunks = read_and_chunk_file('p2025.txt')

print("Creating summary pyramid...")
pyramid = create_summary_pyramid(chunks)

print("Processing chunks and adding to database...")
for layer, layer_chunks in enumerate(pyramid):
    for chunk in tqdm(layer_chunks, desc=f"Processing layer {layer}"):
        print(f"Encoding chunk (length: {len(chunk)})")
        embedding, shape = encode_text(chunk)
        print(f"Adding chunk to database (embedding shape: {shape}, layer: {layer})")
        add_chunk(chunk, embedding, shape, layer)

print(f"Added {sum(len(layer) for layer in pyramid)} chunks to the database.")

def retrieve_chunks(query, top_k=5):
    print(f"Retrieving chunks for query: '{query}'")
    query_embedding, query_shape = encode_text(query)
    print(f"Query embedding shape: {query_shape}")
    
    cursor.execute('SELECT id, embedding, shape, layer FROM document_chunks')
    results = cursor.fetchall()
    
    print(f"Comparing query to {len(results)} stored chunks")
    similarities = []
    for id, emb, shape, layer in tqdm(results, desc="Comparing embeddings"):
        emb_array = np.array([float(x) for x in emb.split(',')]).reshape(eval(shape))
        
        if emb_array.shape != query_shape:
            print(f"Warning: Embedding shape mismatch. Query: {query_shape}, Stored: {emb_array.shape}")
            continue
        
        similarity = np.dot(query_embedding, emb_array) / (np.linalg.norm(query_embedding) * np.linalg.norm(emb_array))
        similarities.append((id, similarity, layer))
    
    if not similarities:
        print("No valid embeddings found for comparison.")
        return []
    
    # Sort by similarity and then by layer (preferring lower layers for equal similarity)
    top_ids = sorted(similarities, key=lambda x: (x[1], -x[2]), reverse=True)[:top_k]
    
    placeholders = ','.join('?' for _ in top_ids)
    cursor.execute(f'SELECT content, layer FROM document_chunks WHERE id IN ({placeholders})', 
                   [id for id, _, _ in top_ids])
    return cursor.fetchall()

print("Testing retrieval...")
test_query = "What is the overall theme of Project 2025?"
relevant_chunks = retrieve_chunks(test_query)

print("\nRelevant chunks for the query:")
for i, (chunk, layer) in enumerate(relevant_chunks, 1):
    print(f"Chunk {i} (Layer {layer}):")
    print(chunk[:200] + "...")  # Print first 200 characters of each chunk
    print()

print("Closing database connection...")
conn.close()
print("Done!")
# Out:
# Setting up OpenAI client...
# Initializing database...
# Creating tables if not exist...
# Reading and chunking file...
# Reading file: p2025.txt
# Chunking file (chunk size: 3500, overlap: 500)
# Chunking progress:   0%|          | 0/2418009 [00:00<?, ?it/s]
# Created 835 chunks
# Creating summary pyramid...
# Creating layer 1...
# Creating layer 2...
# Creating layer 3...
# Creating layer 4...
# Processing chunks and adding to database...
# Processing layer 0:   0%|          | 0/835 [00:00<?, ?it/s]
# Encoding chunk (length: 3500)
# Starting to encode text of length 3500
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3500)
# Starting to encode text of length 3500
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 2880)
# Starting to encode text of length 2880
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3419)
# Starting to encode text of length 3419
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3469)
# Starting to encode text of length 3469
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3463)
# Starting to encode text of length 3463
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3402)
# Starting to encode text of length 3402
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3439)
# Starting to encode text of length 3439
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3445)
# Starting to encode text of length 3445
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3492)
# Starting to encode text of length 3492
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3473)
# Starting to encode text of length 3473
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3409)
# Starting to encode text of length 3409
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3422)
# Starting to encode text of length 3422
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3113)
# Starting to encode text of length 3113
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 2821)
# Starting to encode text of length 2821
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3478)
# Starting to encode text of length 3478
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3296)
# Starting to encode text of length 3296
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3410)
# Starting to encode text of length 3410
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3376)
# Starting to encode text of length 3376
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3456)
# Starting to encode text of length 3456
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3062)
# Starting to encode text of length 3062
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3471)
# Starting to encode text of length 3471
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3394)
# Starting to encode text of length 3394
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3408)
# Starting to encode text of length 3408
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3466)
# Starting to encode text of length 3466
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3485)
# Starting to encode text of length 3485
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3394)
# Starting to encode text of length 3394
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3356)
# Starting to encode text of length 3356
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3440)
# Starting to encode text of length 3440
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3485)
# Starting to encode text of length 3485
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3297)
# Starting to encode text of length 3297
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3463)
# Starting to encode text of length 3463
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3412)
# Starting to encode text of length 3412
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3497)
# Starting to encode text of length 3497
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3451)
# Starting to encode text of length 3451
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3425)
# Starting to encode text of length 3425
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3447)
# Starting to encode text of length 3447
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3185)
# Starting to encode text of length 3185
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3324)
# Starting to encode text of length 3324
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3485)
# Starting to encode text of length 3485
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3307)
# Starting to encode text of length 3307
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3390)
# Starting to encode text of length 3390
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3442)
# Starting to encode text of length 3442
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3405)
# Starting to encode text of length 3405
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3458)
# Starting to encode text of length 3458
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3420)
# Starting to encode text of length 3420
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3441)
# Starting to encode text of length 3441
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3423)
# Starting to encode text of length 3423
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3493)
# Starting to encode text of length 3493
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3332)
# Starting to encode text of length 3332
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3385)
# Starting to encode text of length 3385
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3362)
# Starting to encode text of length 3362
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3483)
# Starting to encode text of length 3483
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3222)
# Starting to encode text of length 3222
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3452)
# Starting to encode text of length 3452
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3437)
# Starting to encode text of length 3437
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3067)
# Starting to encode text of length 3067
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3285)
# Starting to encode text of length 3285
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3476)
# Starting to encode text of length 3476
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3315)
# Starting to encode text of length 3315
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3357)
# Starting to encode text of length 3357
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3225)
# Starting to encode text of length 3225
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3320)
# Starting to encode text of length 3320
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3450)
# Starting to encode text of length 3450
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3424)
# Starting to encode text of length 3424
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3387)
# Starting to encode text of length 3387
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3435)
# Starting to encode text of length 3435
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3490)
# Starting to encode text of length 3490
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3367)
# Starting to encode text of length 3367
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3198)
# Starting to encode text of length 3198
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3381)
# Starting to encode text of length 3381
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3382)
# Starting to encode text of length 3382
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3499)
# Starting to encode text of length 3499
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3303)
# Starting to encode text of length 3303
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3470)
# Starting to encode text of length 3470
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3245)
# Starting to encode text of length 3245
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3317)
# Starting to encode text of length 3317
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3485)
# Starting to encode text of length 3485
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3473)
# Starting to encode text of length 3473
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3421)
# Starting to encode text of length 3421
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3488)
# Starting to encode text of length 3488
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3424)
# Starting to encode text of length 3424
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3492)
# Starting to encode text of length 3492
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3433)
# Starting to encode text of length 3433
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3401)
# Starting to encode text of length 3401
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3500)
# Starting to encode text of length 3500
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3466)
# Starting to encode text of length 3466
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3395)
# Starting to encode text of length 3395
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3481)
# Starting to encode text of length 3481
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3327)
# Starting to encode text of length 3327
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3395)
# Starting to encode text of length 3395
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3372)
# Starting to encode text of length 3372
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3356)
# Starting to encode text of length 3356
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3360)
# Starting to encode text of length 3360
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3460)
# Starting to encode text of length 3460
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3484)
# Starting to encode text of length 3484
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3425)
# Starting to encode text of length 3425
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3489)
# Starting to encode text of length 3489
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3494)
# Starting to encode text of length 3494
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3483)
# Starting to encode text of length 3483
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3463)
# Starting to encode text of length 3463
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3425)
# Starting to encode text of length 3425
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3440)
# Starting to encode text of length 3440
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3474)
# Starting to encode text of length 3474
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3221)
# Starting to encode text of length 3221
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3410)
# Starting to encode text of length 3410
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3365)
# Starting to encode text of length 3365
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3461)
# Starting to encode text of length 3461
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3450)
# Starting to encode text of length 3450
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3463)
# Starting to encode text of length 3463
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3480)
# Starting to encode text of length 3480
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3447)
# Starting to encode text of length 3447
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3423)
# Starting to encode text of length 3423
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3433)
# Starting to encode text of length 3433
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3441)
# Starting to encode text of length 3441
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3495)
# Starting to encode text of length 3495
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3430)
# Starting to encode text of length 3430
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3377)
# Starting to encode text of length 3377
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3461)
# Starting to encode text of length 3461
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3469)
# Starting to encode text of length 3469
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3500)
# Starting to encode text of length 3500
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3365)
# Starting to encode text of length 3365
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3470)
# Starting to encode text of length 3470
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3210)
# Starting to encode text of length 3210
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3426)
# Starting to encode text of length 3426
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3469)
# Starting to encode text of length 3469
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3427)
# Starting to encode text of length 3427
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3394)
# Starting to encode text of length 3394
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3437)
# Starting to encode text of length 3437
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3493)
# Starting to encode text of length 3493
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3378)
# Starting to encode text of length 3378
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3489)
# Starting to encode text of length 3489
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3219)
# Starting to encode text of length 3219
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3445)
# Starting to encode text of length 3445
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3479)
# Starting to encode text of length 3479
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3486)
# Starting to encode text of length 3486
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3321)
# Starting to encode text of length 3321
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3486)
# Starting to encode text of length 3486
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3319)
# Starting to encode text of length 3319
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3471)
# Starting to encode text of length 3471
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3431)
# Starting to encode text of length 3431
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3409)
# Starting to encode text of length 3409
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3447)
# Starting to encode text of length 3447
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3466)
# Starting to encode text of length 3466
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3400)
# Starting to encode text of length 3400
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3443)
# Starting to encode text of length 3443
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3395)
# Starting to encode text of length 3395
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3365)
# Starting to encode text of length 3365
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3323)
# Starting to encode text of length 3323
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3310)
# Starting to encode text of length 3310
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3499)
# Starting to encode text of length 3499
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3482)
# Starting to encode text of length 3482
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3371)
# Starting to encode text of length 3371
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3342)
# Starting to encode text of length 3342
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3446)
# Starting to encode text of length 3446
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3448)
# Starting to encode text of length 3448
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3228)
# Starting to encode text of length 3228
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3457)
# Starting to encode text of length 3457
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3453)
# Starting to encode text of length 3453
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3412)
# Starting to encode text of length 3412
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3337)
# Starting to encode text of length 3337
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3411)
# Starting to encode text of length 3411
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3387)
# Starting to encode text of length 3387
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3457)
# Starting to encode text of length 3457
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3419)
# Starting to encode text of length 3419
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3300)
# Starting to encode text of length 3300
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3447)
# Starting to encode text of length 3447
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3413)
# Starting to encode text of length 3413
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3430)
# Starting to encode text of length 3430
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3483)
# Starting to encode text of length 3483
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3417)
# Starting to encode text of length 3417
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3240)
# Starting to encode text of length 3240
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3369)
# Starting to encode text of length 3369
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3490)
# Starting to encode text of length 3490
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3238)
# Starting to encode text of length 3238
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3389)
# Starting to encode text of length 3389
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3464)
# Starting to encode text of length 3464
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3483)
# Starting to encode text of length 3483
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3448)
# Starting to encode text of length 3448
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3310)
# Starting to encode text of length 3310
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3475)
# Starting to encode text of length 3475
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3470)
# Starting to encode text of length 3470
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3379)
# Starting to encode text of length 3379
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3099)
# Starting to encode text of length 3099
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3455)
# Starting to encode text of length 3455
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3470)
# Starting to encode text of length 3470
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3487)
# Starting to encode text of length 3487
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3440)
# Starting to encode text of length 3440
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3456)
# Starting to encode text of length 3456
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3387)
# Starting to encode text of length 3387
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3393)
# Starting to encode text of length 3393
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3453)
# Starting to encode text of length 3453
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3429)
# Starting to encode text of length 3429
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3317)
# Starting to encode text of length 3317
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3359)
# Starting to encode text of length 3359
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3419)
# Starting to encode text of length 3419
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3488)
# Starting to encode text of length 3488
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3480)
# Starting to encode text of length 3480
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3430)
# Starting to encode text of length 3430
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3119)
# Starting to encode text of length 3119
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3369)
# Starting to encode text of length 3369
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3291)
# Starting to encode text of length 3291
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3400)
# Starting to encode text of length 3400
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3361)
# Starting to encode text of length 3361
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3334)
# Starting to encode text of length 3334
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3304)
# Starting to encode text of length 3304
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3414)
# Starting to encode text of length 3414
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3337)
# Starting to encode text of length 3337
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3345)
# Starting to encode text of length 3345
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3495)
# Starting to encode text of length 3495
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3416)
# Starting to encode text of length 3416
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3375)
# Starting to encode text of length 3375
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3412)
# Starting to encode text of length 3412
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3410)
# Starting to encode text of length 3410
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3436)
# Starting to encode text of length 3436
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3416)
# Starting to encode text of length 3416
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3264)
# Starting to encode text of length 3264
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3400)
# Starting to encode text of length 3400
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3439)
# Starting to encode text of length 3439
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3366)
# Starting to encode text of length 3366
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3392)
# Starting to encode text of length 3392
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3329)
# Starting to encode text of length 3329
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3437)
# Starting to encode text of length 3437
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3429)
# Starting to encode text of length 3429
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3225)
# Starting to encode text of length 3225
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3318)
# Starting to encode text of length 3318
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3375)
# Starting to encode text of length 3375
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3166)
# Starting to encode text of length 3166
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3350)
# Starting to encode text of length 3350
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3472)
# Starting to encode text of length 3472
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3389)
# Starting to encode text of length 3389
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3481)
# Starting to encode text of length 3481
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3468)
# Starting to encode text of length 3468
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3449)
# Starting to encode text of length 3449
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3481)
# Starting to encode text of length 3481
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3356)
# Starting to encode text of length 3356
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3417)
# Starting to encode text of length 3417
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3265)
# Starting to encode text of length 3265
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3304)
# Starting to encode text of length 3304
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3455)
# Starting to encode text of length 3455
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3481)
# Starting to encode text of length 3481
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3491)
# Starting to encode text of length 3491
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3453)
# Starting to encode text of length 3453
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3329)
# Starting to encode text of length 3329
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3482)
# Starting to encode text of length 3482
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3431)
# Starting to encode text of length 3431
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3487)
# Starting to encode text of length 3487
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3427)
# Starting to encode text of length 3427
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3487)
# Starting to encode text of length 3487
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3392)
# Starting to encode text of length 3392
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3378)
# Starting to encode text of length 3378
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3163)
# Starting to encode text of length 3163
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3254)
# Starting to encode text of length 3254
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3488)
# Starting to encode text of length 3488
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3481)
# Starting to encode text of length 3481
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3207)
# Starting to encode text of length 3207
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3479)
# Starting to encode text of length 3479
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3373)
# Starting to encode text of length 3373
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3200)
# Starting to encode text of length 3200
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3480)
# Starting to encode text of length 3480
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# Encoding chunk (length: 3387)
# Starting to encode text of length 3387
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 0)
# ...
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 987)
# Starting to encode text of length 987
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 939)
# Starting to encode text of length 939
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 1210)
# Starting to encode text of length 1210
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 934)
# Starting to encode text of length 934
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 782)
# Starting to encode text of length 782
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 948)
# Starting to encode text of length 948
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 765)
# Starting to encode text of length 765
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 1001)
# Starting to encode text of length 1001
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 1047)
# Starting to encode text of length 1047
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 733)
# Starting to encode text of length 733
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 976)
# Starting to encode text of length 976
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 759)
# Starting to encode text of length 759
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 767)
# Starting to encode text of length 767
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 815)
# Starting to encode text of length 815
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 860)
# Starting to encode text of length 860
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 935)
# Starting to encode text of length 935
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 769)
# Starting to encode text of length 769
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 962)
# Starting to encode text of length 962
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 1042)
# Starting to encode text of length 1042
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 739)
# Starting to encode text of length 739
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 773)
# Starting to encode text of length 773
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 1419)
# Starting to encode text of length 1419
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 967)
# Starting to encode text of length 967
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 1263)
# Starting to encode text of length 1263
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 982)
# Starting to encode text of length 982
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Encoding chunk (length: 952)
# Starting to encode text of length 952
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 3)
# Processing layer 4:   0%|          | 0/53 [00:00<?, ?it/s]
# Encoding chunk (length: 763)
# Starting to encode text of length 763
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 761)
# Starting to encode text of length 761
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 793)
# Starting to encode text of length 793
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 905)
# Starting to encode text of length 905
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1209)
# Starting to encode text of length 1209
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1060)
# Starting to encode text of length 1060
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 883)
# Starting to encode text of length 883
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 953)
# Starting to encode text of length 953
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1207)
# Starting to encode text of length 1207
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 769)
# Starting to encode text of length 769
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 829)
# Starting to encode text of length 829
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1169)
# Starting to encode text of length 1169
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1270)
# Starting to encode text of length 1270
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1164)
# Starting to encode text of length 1164
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 955)
# Starting to encode text of length 955
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1038)
# Starting to encode text of length 1038
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1146)
# Starting to encode text of length 1146
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1367)
# Starting to encode text of length 1367
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 910)
# Starting to encode text of length 910
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 854)
# Starting to encode text of length 854
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 914)
# Starting to encode text of length 914
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 685)
# Starting to encode text of length 685
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 943)
# Starting to encode text of length 943
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1488)
# Starting to encode text of length 1488
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 999)
# Starting to encode text of length 999
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1092)
# Starting to encode text of length 1092
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 755)
# Starting to encode text of length 755
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1249)
# Starting to encode text of length 1249
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1115)
# Starting to encode text of length 1115
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1075)
# Starting to encode text of length 1075
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 719)
# Starting to encode text of length 719
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 766)
# Starting to encode text of length 766
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 795)
# Starting to encode text of length 795
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1094)
# Starting to encode text of length 1094
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 889)
# Starting to encode text of length 889
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1173)
# Starting to encode text of length 1173
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1429)
# Starting to encode text of length 1429
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 654)
# Starting to encode text of length 654
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 913)
# Starting to encode text of length 913
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 942)
# Starting to encode text of length 942
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1099)
# Starting to encode text of length 1099
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 754)
# Starting to encode text of length 754
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 818)
# Starting to encode text of length 818
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 859)
# Starting to encode text of length 859
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 630)
# Starting to encode text of length 630
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1044)
# Starting to encode text of length 1044
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 949)
# Starting to encode text of length 949
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 830)
# Starting to encode text of length 830
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1307)
# Starting to encode text of length 1307
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 686)
# Starting to encode text of length 686
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 879)
# Starting to encode text of length 879
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 1233)
# Starting to encode text of length 1233
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Encoding chunk (length: 952)
# Starting to encode text of length 952
# Attempt 1 to encode text
# Successfully encoded text
# Adding chunk to database (embedding shape: (1536,), layer: 4)
# Added 1620 chunks to the database.
# Testing retrieval...
# Retrieving chunks for query: 'What is the overall theme of Project 2025?'
# Starting to encode text of length 42
# Attempt 1 to encode text
# Successfully encoded text
# Query embedding shape: (1536,)
# Comparing query to 1620 stored chunks
# Comparing embeddings:   0%|          | 0/1620 [00:00<?, ?it/s]
# Relevant chunks for the query:
# Chunk 1 (Layer 0):
# nder, Senior Graphic Designer Grace Desandro, and Senior Designer Melissa
# Bluey came together to bring the volume to life. We also thank the dedicated junior
# staff who provided immeasurable assistan...
#
# Chunk 2 (Layer 1):
# "Mandate for Leadership 2025: The Conservative Promise" is a collective work aimed at advancing positive change in America, contributed by various volunteers and conservative thinkers. While acknowled...
#
# Chunk 3 (Layer 1):
# Project 2025 aims to prepare the next conservative President to govern the increasingly complex and growing federal government. The project plans to build an army of trained and ready conservatives to...
#
# Chunk 4 (Layer 2):
# The "Project 2025 Presidential Transition Project" is a comprehensive document by the Heritage Foundation covering diverse topics, including governmental operations, defense, public welfare, economy, ...
#
# Chunk 5 (Layer 2):
# Project 2025 is an initiative aimed at preparing the next conservative President to lead and govern the US federal government. The project focuses on four aspects: establishing consensus on government...
#
# Closing database connection...
# Done!
